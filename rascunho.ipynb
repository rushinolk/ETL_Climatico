# %%
import pandas as pd 
import requests
import config
import logging

# %%
api_url = config.CLIMA_API

# Parametros da API
parametros_api = {
    "latitude": -21.75,
    "longitude": -45.33,
    "daily":"temperature_2m_max,temperature_2m_min,precipitation_sum",
    "timezone":"America/Sao_Paulo"
}


response = requests.get(api_url,params=parametros_api,timeout=10)

response.raise_for_status()

raw_data = response.json()
logging.info(f"Extração de dados concluida. {len(raw_data['daily']['time'])} dias de previsão recebidos")

# %%
df = pd.DataFrame(raw_data)
df.head(5)
# Out:
#                     latitude  longitude  generationtime_ms  \
# time                  -21.75    -45.375           0.045538
# temperature_2m_max    -21.75    -45.375           0.045538
# temperature_2m_min    -21.75    -45.375           0.045538
# precipitation_sum     -21.75    -45.375           0.045538
#
#                     utc_offset_seconds           timezone  \
# time                            -10800  America/Sao_Paulo
# temperature_2m_max              -10800  America/Sao_Paulo
# temperature_2m_min              -10800  America/Sao_Paulo
# precipitation_sum               -10800  America/Sao_Paulo
#
#                    timezone_abbreviation  elevation daily_units  \
# time                               GMT-3      858.0     iso8601
# temperature_2m_max                 GMT-3      858.0          °C
# temperature_2m_min                 GMT-3      858.0          °C
# precipitation_sum                  GMT-3      858.0          mm
#
#                                                                 daily
# time                [2025-10-28, 2025-10-29, 2025-10-30, 2025-10-3...
# temperature_2m_max         [25.8, 29.2, 26.2, 21.8, 24.9, 23.4, 23.7]
# temperature_2m_min         [19.1, 19.2, 18.7, 17.3, 17.8, 19.4, 19.7]
# precipitation_sum             [1.4, 0.2, 18.4, 11.8, 5.4, 15.1, 19.1]
